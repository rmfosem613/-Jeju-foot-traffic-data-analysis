# %% [markdown]
# <a href="https://colab.research.google.com/github/rmfosem613/-Jeju-foot-traffic-data-analysis/blob/master/2015_%EC%A0%9C%EC%A3%BC_%EC%9C%A0%EB%8F%99%EC%9D%B8%EA%B5%AC_%EC%A1%B0%EC%82%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
fpop = pd.read_csv('/content/fpop_data.csv', encoding='CP949')
#CP949 -> 마이크로소프트가 제정한 한글 인코딩 방법의 한 종류이며, 한글윈도우 운영체제의 기본 인코딩 방법임

# %%
type(fpop)   # 데이터형
# Out:
# pandas.core.frame.DataFrame

# %%
fpop.index   #각 행별 색인번호
# Out:
# RangeIndex(start=0, stop=57832, step=1)

# %%
fpop         # 전체 데이터 보기
# Out:
#          기준년월                 지번코드  ... 50대 여자 유동인구 비율  60대 여자 유동인구 비율
# 0      201507  5011025021137710000  ...   2.297560e-05        0.000028
# 1      201507  5011025021140370002  ...   3.019794e-06        0.000002
# 2      201507  5011025021131660000  ...   3.774743e-08        0.000000
# 3      201507  5011025021109960000  ...   2.597023e-05        0.000029
# 4      201507  5011025021110250005  ...   3.357004e-05        0.000034
# ...       ...                  ...  ...            ...             ...
# 57827  201507  5013010400120230000  ...   0.000000e+00        0.000000
# 57828  201507  5013010400120550000  ...   0.000000e+00        0.000000
# 57829  201507  5013010600117810002  ...   0.000000e+00        0.000000
# 57830  201507  5013025326100710000  ...   0.000000e+00        0.000000
# 57831  201507  5011012100126060000  ...   0.000000e+00        0.000000
#
# [57832 rows x 27 columns]

# %%
fpop.describe()       #통계요약
# Out:
#            기준년월          지번코드  ...  50대 여자 유동인구 비율  60대 여자 유동인구 비율
# count   57832.0  5.783200e+04  ...    5.783200e+04    5.783200e+04
# mean   201507.0  5.011931e+18  ...    1.729146e-05    1.729146e-05
# std         0.0  9.968424e+14  ...    8.710403e-05    8.905242e-05
# min    201507.0  5.011010e+18  ...    0.000000e+00    0.000000e+00
# 25%    201507.0  5.011025e+18  ...    8.807733e-08    2.218135e-08
# 50%    201507.0  5.011028e+18  ...    9.814331e-07    5.323525e-07
# 75%    201507.0  5.013025e+18  ...    8.832898e-06    7.164577e-06
# max    201507.0  5.013032e+18  ...    6.390299e-03    6.605762e-03
#
# [8 rows x 26 columns]

# %%
fpop.columns         # 데이터프레임의 열(컬럼) 출력
# Out:
# Index(['기준년월', '지번코드', '지번명', '10대이하 남자 유동인구', '20대 남자 유동인구', '30대 남자 유동인구',
#        '40대 남자 유동인구', '50대 남자 유동인구', '60대이상 남자 유동인구', '10대이하 여자 유동인구',
#        '20대 여자 유동인구', '30대 여자 유동인구', '40대 여자 유동인구', '50대 여자 유동인구',
#        '60대이상 여자 유동인구', '10대이하 남자 유동인구 비율', '20대 남자 유동인구 비율', '30대 남자 유동인구 비율',
#        '40대 남자 유동인구 비율', '50대 남자 유동인구 비율', '60대이상 남자 유동인구 비율',
#        '10대이하 여자 유동인구 비율', '20대 여자 유동인구 비율', '30대 여자 유동인구 비율',
#        '40대 여자 유동인구 비율', '50대 여자 유동인구 비율', '60대 여자 유동인구 비율'],
#       dtype='object')

# %%
fpop.지번명
# Out:
# 0        제주특별자치도 제주시 한림읍 귀덕리 1 3771-0
# 1        제주특별자치도 제주시 한림읍 귀덕리 1 4037-2
# 2        제주특별자치도 제주시 한림읍 귀덕리 1 3166-0
# 3         제주특별자치도 제주시 한림읍 귀덕리 1 996-0
# 4        제주특별자치도 제주시 한림읍 귀덕리 1 1025-5
#                      ...
# 57827       제주특별자치도 서귀포시 호근동 1 2023-0
# 57828       제주특별자치도 서귀포시 호근동 1 2055-0
# 57829       제주특별자치도 서귀포시 서홍동 1 1781-2
# 57830     제주특별자치도 서귀포시 남원읍 신흥리 1 71-0
# 57831       제주특별자치도 제주시 오라삼동 1 2606-0
# Name: 지번명, Length: 57832, dtype: object

# %%
type(fpop.지번명 )
#Serise 타입 => Series 데이터형의 요소접근(인덱싱) 방법 숙지
# Out:
# pandas.core.series.Series

# %%
pname = fpop.지번명

# %%
pname[1:100] # 1에서 99번째 행의 지역이름 출력
# Out:
# 1     제주특별자치도 제주시 한림읍 귀덕리 1 4037-2
# 2     제주특별자치도 제주시 한림읍 귀덕리 1 3166-0
# 3      제주특별자치도 제주시 한림읍 귀덕리 1 996-0
# 4     제주특별자치도 제주시 한림읍 귀덕리 1 1025-5
# 5     제주특별자치도 제주시 한림읍 귀덕리 1 3861-0
#                   ...
# 95    제주특별자치도 제주시 한림읍 귀덕리 1 3031-1
# 96    제주특별자치도 제주시 한림읍 귀덕리 1 3032-2
# 97    제주특별자치도 제주시 한림읍 귀덕리 1 1212-5
# 98    제주특별자치도 제주시 한림읍 귀덕리 1 1236-2
# 99    제주특별자치도 제주시 한림읍 귀덕리 1 1091-0
# Name: 지번명, Length: 99, dtype: object

# %%
pname[5][0:7]
# Out:
# '제주특별자치도'

# %%
pname[7][0:10]       # 7번째 행의 지역이름 출력
# Out:
# '제주특별자치도 제주'

# %%
pname[1:100][0:10]
# Out:
# 1     제주특별자치도 제주시 한림읍 귀덕리 1 4037-2
# 2     제주특별자치도 제주시 한림읍 귀덕리 1 3166-0
# 3      제주특별자치도 제주시 한림읍 귀덕리 1 996-0
# 4     제주특별자치도 제주시 한림읍 귀덕리 1 1025-5
# 5     제주특별자치도 제주시 한림읍 귀덕리 1 3861-0
# 6     제주특별자치도 제주시 한림읍 귀덕리 1 3772-0
# 7      제주특별자치도 제주시 한림읍 귀덕리 1 170-3
# 8      제주특별자치도 제주시 한림읍 귀덕리 1 147-0
# 9     제주특별자치도 제주시 한림읍 귀덕리 1 1195-1
# 10    제주특별자치도 제주시 한림읍 귀덕리 1 3254-5
# Name: 지번명, dtype: object

# %%
i = 0
A1 = []    # Area 1: 도단위 (리스트 데이터)
A2 = []    # Area2 : 시단위
A3 = []    # Area3 : 읍면동 단위
while i < len(fpop):
    temp = pname[i].split()   # 지역이름은 공백 기준으로 분리하여 리스트형으로 돌려줌 => Series형의 split()함수 사용
    A1.insert(i,temp[0]) # '제주특별자치도' 추출후 a1 리스트변수에 추가
    A2.insert(i,temp[1]) # '제주시'or '서귀포시' 추출후 a2 리스트변수에 추가
    A3.insert(i,temp[2]) #  읍명동 추출후 a3 리스트변수에 추가
    i = i + 1

# %%
A3
# Out:
# ['한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
#  '한림읍',
# ...

# %%
type(A1)
# Out:
# list

# %%
len(A1)
# Out:
# 57832

# %%
fpop['A1'] = A1   # fpop(유동인구 데이터)에 A1 열 추가
fpop['A2'] = A2   # fpop(유동인구 데이터)에 A2 열 추가
fpop['A3'] = A3   # fpop(유동인구 데이터)에 A3 열 추가

# %%
fpop.columns       # 추가된 열 확인
# Out:
# Index(['기준년월', '지번코드', '지번명', '10대이하 남자 유동인구', '20대 남자 유동인구', '30대 남자 유동인구',
#        '40대 남자 유동인구', '50대 남자 유동인구', '60대이상 남자 유동인구', '10대이하 여자 유동인구',
#        '20대 여자 유동인구', '30대 여자 유동인구', '40대 여자 유동인구', '50대 여자 유동인구',
#        '60대이상 여자 유동인구', '10대이하 남자 유동인구 비율', '20대 남자 유동인구 비율', '30대 남자 유동인구 비율',
#        '40대 남자 유동인구 비율', '50대 남자 유동인구 비율', '60대이상 남자 유동인구 비율',
#        '10대이하 여자 유동인구 비율', '20대 여자 유동인구 비율', '30대 여자 유동인구 비율',
#        '40대 여자 유동인구 비율', '50대 여자 유동인구 비율', '60대 여자 유동인구 비율', 'A1', 'A2', 'A3'],
#       dtype='object')

# %%
group_fpop = fpop.groupby(['A3']).sum()     #데이터프레임 fpop에서 A3열을 기준으로 그룹핑 및 합계계산

# %%
type(group_fpop)
# Out:
# pandas.core.frame.DataFrame

# %%
group_fpop.columns
# Out:
# Index(['기준년월', '지번코드', '10대이하 남자 유동인구', '20대 남자 유동인구', '30대 남자 유동인구',
#        '40대 남자 유동인구', '50대 남자 유동인구', '60대이상 남자 유동인구', '10대이하 여자 유동인구',
#        '20대 여자 유동인구', '30대 여자 유동인구', '40대 여자 유동인구', '50대 여자 유동인구',
#        '60대이상 여자 유동인구', '10대이하 남자 유동인구 비율', '20대 남자 유동인구 비율', '30대 남자 유동인구 비율',
#        '40대 남자 유동인구 비율', '50대 남자 유동인구 비율', '60대이상 남자 유동인구 비율',
#        '10대이하 여자 유동인구 비율', '20대 여자 유동인구 비율', '30대 여자 유동인구 비율',
#        '40대 여자 유동인구 비율', '50대 여자 유동인구 비율', '60대 여자 유동인구 비율'],
#       dtype='object')

# %%
group_fpop
# Out:
#              기준년월          지번코드  ...  50대 여자 유동인구 비율  60대 여자 유동인구 비율
# A3                               ...
# 강정동   190222608.0  4.732283e+21  ...        0.013552        0.014800
# 건입동    49570722.0  1.232709e+21  ...        0.017021        0.016800
# 구좌읍   672025845.0  1.671177e+22  ...        0.031825        0.031783
# 남원읍   804214437.0  2.000698e+22  ...        0.016513        0.019137
# 내도동    35062218.0  8.719164e+20  ...        0.000097        0.000046
# ...           ...           ...  ...             ...             ...
# 호근동    86648010.0  2.155594e+21  ...        0.000541        0.000215
# 화북이동  100350486.0  2.495484e+21  ...        0.001310        0.001143
# 화북일동  125538861.0  3.121860e+21  ...        0.011835        0.014441
# 회수동    34457697.0  8.572249e+20  ...        0.000535        0.000438
# 회천동    73751562.0  1.834031e+21  ...        0.000708        0.000386
#
# [73 rows x 26 columns]

# %%
len(group_fpop )
# Out:
# 73

# %%
### 73개  읍면동 별 MAN(남자), WOMAN(여자), TOTAL(전체) 유동인구수 계산
### 반복문 사용####################################################
i = 0
TOTAL = []
WOMAN = []
MAN = []

# %%
while i < len(group_fpop):
    each_MAN = group_fpop.ix[i]['10대이하 남자 유동인구'] + group_fpop.ix[i]['20대 남자 유동인구']+ group_fpop.ix[i]['30대 남자 유동인구']+ group_fpop.ix[i]['40대 남자 유동인구']+ group_fpop.ix[i]['50대 남자 유동인구']+group_fpop.ix[i]['60대이상 남자 유동인구']
    MAN.insert(i,each_MAN)
    each_WOMAN = group_fpop.ix[i]['10대이하 여자 유동인구'] +group_fpop.ix[i]['20대 여자 유동인구']+ group_fpop.ix[i]['30대 여자 유동인구']+ group_fpop.ix[i]['40대 여자 유동인구']+ group_fpop.ix[i]['50대 여자 유동인구']+ group_fpop.ix[i]['60대이상 여자 유동인구']
    WOMAN.insert(i,each_WOMAN)  
    each_TOTAL = each_MAN + each_WOMAN
    TOTAL.insert(i,each_TOTAL)     
    i = i + 1

# %%
group_fpop['MAN'] = MAN
group_fpop['WOMAN'] = WOMAN
group_fpop['TOTAL'] = TOTAL

# %%
group_fpop
# Out:
#              기준년월          지번코드  10대이하 남자 유동인구  ...      MAN    WOMAN     TOTAL
# A3                                              ...
# 강정동   190222608.0  4.732283e+21          99.13  ...  3248.21  2113.70   5361.91
# 건입동    49570722.0  1.232709e+21         109.33  ...  3173.90  2356.65   5530.55
# 구좌읍   672025845.0  1.671177e+22         248.17  ...  6106.65  6486.31  12592.96
# 남원읍   804214437.0  2.000698e+22          86.62  ...  3030.48  2492.89   5523.37
# 내도동    35062218.0  8.719164e+20           0.20  ...    31.04    18.42     49.46
# ...           ...           ...            ...  ...      ...      ...       ...
# 호근동    86648010.0  2.155594e+21           0.79  ...   157.61   101.67    259.28
# 화북이동  100350486.0  2.495484e+21           5.03  ...   275.17   180.20    455.37
# 화북일동  125538861.0  3.121860e+21          87.28  ...  2418.52  1702.62   4121.14
# 회수동    34457697.0  8.572249e+20           1.81  ...   124.94    94.31    219.25
# ...

# %%
group_fpop_new =group_fpop[['10대이하 남자 유동인구', '20대 남자 유동인구', '30대 남자 유동인구',
       '40대 남자 유동인구', '50대 남자 유동인구', '60대이상 남자 유동인구', '10대이하 여자 유동인구',
       '20대 여자 유동인구', '30대 여자 유동인구', '40대 여자 유동인구', '50대 여자 유동인구',
       '60대이상 여자 유동인구', 'MAN', 'WOMAN', 'TOTAL' ]]

# %%
group_fpop_new.to_csv('/content/group_fpop.csv', encoding='CP949')
#fpop_new에 저장된 데이터프레임을 group_fpop.csv로 영구히 저장

# %%
###############################################################
#시각화
################################################################
import matplotlib  as mpl
import matplotlib.pyplot as plt

# %%
group_fpop= pd.read_csv('/content/group_fpop.csv', encoding='CP949')

# %%
plt.figure(figsize=(20,10))
plt.xlabel("읍면동")
plt.ylabel(" 유동인구수")
plt.title(" 제주지역 읍변동 별 유동인구 분포")
plt.plot(group_fpop.A3, group_fpop.TOTAL)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.plot(group_fpop.A3, group_fpop.TOTAL, 'bo')  #파란색 점 그래프
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.plot(group_fpop.A3, group_fpop.MAN, 'bo')
plt.title("읍면동 별 남자 분포")
plt.subplot(222)
plt.plot(group_fpop.A3, group_fpop.WOMAN, 'ro')
plt.title("읍면동 별 여자 분포")
plt.subplot(223)
plt.plot(group_fpop.A3, group_fpop.TOTAL, 'go')
plt.title("읍면동 별 전체 분포")
# Out:
# Text(0.5, 1.0, '읍면동 별 전체 분포')
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
